# %%
import pandas as pd
import numpy as np
from pybaseball import statcast
from pybaseball import pitching_stats
from pybaseball import playerid_lookup
from pybaseball import statcast_pitcher

# %%
playerid_lookup('verlander', 'justin')
# Out:
# Gathering player lookup table. This may take a moment.
#    name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0  verlander     justin     434378  verlj001  verlaju01           8700
#
#    mlb_played_first  mlb_played_last
# 0            2005.0           2020.0

# %%
bieber_lookup = statcast_pitcher('2014-03-22', '2020-09-08', 434378)
# Out:
# Gathering Player Data

# %%
bieber_lookup.release_spin_rate
# Out:
# 0     2436.0
# 1     2443.0
# 2     2480.0
# 3     2504.0
# 4     2445.0
#        ...
# 68    2642.0
# 69    2497.0
# 70    2818.0
# 71    2526.0
# 72    2498.0
# Name: release_spin_rate, Length: 21228, dtype: float64

# %%
brefdf = pd.read_csv("pitching_season_data_2014_to_2019.csv")

# %%
fgdf = pitching_stats(2014,2019)

# %%
fgdf.loc[fgdf['Name'] == "Tim Adleman"]
# Out:
#       Season         Name  Team   Age    W     L   ERA  WAR     G    GS  ...  \
# 1895  2016.0  Tim Adleman  Reds  28.0  4.0   4.0  4.00  0.1  13.0  13.0  ...
# 3196  2017.0  Tim Adleman  Reds  29.0  5.0  11.0  5.52 -0.3  30.0  20.0  ...
#
#       wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  \
# 1895         NaN         NaN          0.296          0.658        0.490
# 3196         NaN         NaN          0.260          0.671        0.471
#
#       O-Contact% (pi)  Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)
# 1895            0.693            0.845          0.803       0.538       22.4
# 3196            0.602            0.836          0.773       0.512       23.0
#
# [2 rows x 299 columns]

# %%
[print(column) for column in brefdf.columns]
# Out:
# Unnamed: 0
# Name
# Age
# #days
# Lev
# Tm
# G
# GS
# W
# L
# SV
# IP
# H
# R
# ER
# BB
# SO
# HR
# HBP
# ERA
# AB
# 2B
# 3B
# IBB
# GDP
# SF
# SB
# CS
# PO
# BF
# Pit
# Str
# StL
# StS
# GB/FB
# LD
# PU
# WHIP
# BAbip
# SO9
# SO/W
# season
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
fgdf = fgdf.loc[(fgdf['GS'] > 4) & (fgdf['IP'] > 50)]

# %%
df = pd.merge(brefdf, fgdf,  how='left', left_on=['Name','season'], right_on = ['Name','Season'])

# %%
pd.set_option('max_columns', 500)

# %%
fgdf
# Out:
#       Season             Name       Team   Age     W     L   ERA  WAR     G  \
# 278   2018.0     Jacob deGrom       Mets  30.0  10.0   9.0  1.70  9.0  32.0
# 386   2015.0  Clayton Kershaw    Dodgers  27.0  16.0   7.0  2.13  8.6  33.0
# 288   2014.0  Clayton Kershaw    Dodgers  26.0  21.0   3.0  1.77  7.9  27.0
# 828   2017.0       Chris Sale    Red Sox  28.0  17.0   8.0  2.90  7.6  32.0
# 575   2018.0     Max Scherzer  Nationals  33.0  18.0   7.0  2.53  7.5  33.0
# ...      ...              ...        ...   ...   ...   ...   ...  ...   ...
# 4180  2019.0    Edwin Jackson      - - -  35.0   3.0  10.0  9.58 -1.1  18.0
# 3933  2017.0      Dylan Covey  White Sox  25.0   0.0   7.0  7.71 -1.1  18.0
# 3536  2016.0      Chris Young     Royals  37.0   3.0   9.0  6.19 -1.2  34.0
# 2794  2018.0    Jarlin Garcia    Marlins  25.0   3.0   3.0  4.91 -1.3  29.0
# 3524  2018.0      Josh Tomlin    Indians  33.0   2.0   5.0  6.14 -1.4  32.0
#
# ...

# %%
df.columns=[col.split('_')[0] for col in df.columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Name                   0
# Age                    0
# #days                  0
# Lev                    0
# Tm                     0
# G                      0
# GS                     0
# W                      7
# L                      1
# SV                  1111
# IP                     0
# H                      0
# R                      0
# ER                     0
# BB                     0
# SO                     0
# HR                     0
# HBP                    0
# ERA                    0
# AB                     0
# 2B                     0
# 3B                     0
# IBB                    0
# GDP                    0
# SF                     0
# SB                     0
# CS                     0
# PO                     0
# BF                     0
# Pit                    0
# Str                    0
# StL                    0
# StS                    0
# GB/FB                  0
# LD                     0
# PU                     0
# ...

# %%
df[df['wSC (pfx)'].isnull() == False]
# Out:
#      Unnamed: 0             Name  Age  #days     Lev                     Tm  \
# 159         601  Hector Santiago   28   1438  MLB-AL  Minnesota,Los Angeles
# 365        1346  Hector Santiago   29   1164  MLB-AL              Minnesota
# 563        2136  Hector Santiago   30    711  MLB-AL                Chicago
#
#       G  GS     W     L   SV     IP    H    R  ER  BB   SO  HR  HBP   ERA  \
# 159  33  33  13.0  10.0  NaN  182.0  169  100  95  79  144  33    5  4.70
# 365  15  14   4.0   8.0  NaN   70.1   70   44  44  31   51  15    5  5.63
# 563  49   7   6.0   3.0  2.0  102.0  101   54  50  60  103  16    5  4.41
#
#       AB  2B  3B  IBB  GDP  SF  SB  CS  PO   BF   Pit   Str   StL   StS  \
# 159  690  34   4    0   11   6   9   7   4  785  3161  0.63  0.17  0.08
# 365  274   6   0    0    3   1   8   1   0  311  1236  0.62  0.16  0.07
# 563  391  23   1    3    9   3   7   3   1  460  1959  0.62  0.17  0.08
#
# ...
